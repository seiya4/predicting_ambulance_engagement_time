# %%
import warnings; warnings.simplefilter('ignore')
import logging, sys
logging.disable(sys.maxsize)
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv
import pickle
from datetime import datetime
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import balanced_accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from multi_freq_ldpy.pure_frequency_oracles.GRR import GRR_Client
from aif360.datasets import BinaryLabelDataset
from aif360.metrics import BinaryLabelDatasetMetric

# %% [markdown]
# # Parameters

# %%
folder_name = "RF_Base"
target = "ind_avg"
SEED = 42

# %% [markdown]
# # Writing function

# %%
def write(folder_name, values):
    with open(folder_name + "/" + folder_name + '_results.csv', mode='a', newline='') as scores_file:
        scores_writer = csv.writer(scores_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        scores_writer.writerow(values)
    scores_file.close()

# %% [markdown]
# # Objective function

# %%
def objective_function(space):
    
    global SEED, ITER, X_train, y_train, X_test, y_test
    
    ITER += 1
    
    params = {'n_estimators': int(space["n_estimators"]), 
              'max_depth': int(space["max_depth"]),
              'max_features': round(space["max_features"],2),
              'max_samples': round(space["max_samples"],2),
              'class_weight': {0:1, 1:2}
              }
    
    print("\n------------------------------------------")
    print("\n", ITER, ":: ", params)
    
    model = RandomForestClassifier(random_state=SEED,
                                   n_jobs=-1
                                )
    model.set_params(**params)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    acc = round(accuracy_score(y_test,y_pred)*100, 2)
    cm = confusion_matrix(y_test, y_pred)
    c0 = round(cm[0,0]/np.sum(cm[0])*100, 2)
    c1 = round(cm[1,1]/np.sum(cm[1])*100, 2)
    report = classification_report(y_test, y_pred, output_dict=True)
    
    loss = 0
    if c0>70 and c1>70: 
        loss = c0*c1
    else:
        loss = c0+c1
        
    # write 
    write(folder_name, [str(ITER),
           loss,
           acc,
           report["macro avg"]["f1-score"],
           report["macro avg"]["precision"],
           report["macro avg"]["recall"],
           c0,
           c1,
           cm,
           classification_report(y_test, y_pred),
           params])
    
    # save files
    dico_files = {}
    dico_files["model"] = model
    dico_files["params"] = params
    dico_files["y_pred"] = y_pred
    pickle.dump(dico_files, open(folder_name + "/" + "/ITER_"+str(ITER)+".dat", "wb"))
    del dico_files

    print("loss", loss)
    print("acc", acc)
    print("f1", report["macro avg"]["f1-score"])
    print("cm", cm)
    print("c0", c0, "c1", c1)
    
    return {'loss':-loss, 'status': STATUS_OK}

# %% [markdown]
# # Preprocessing data

# %% [markdown]
# ## Reading data

# %%
df = pd.read_csv("dataset_classification.csv")
df["alert"] = pd.to_datetime(df["alert"])
df.sort_values(by="alert", ascending=True, inplace=True)
print("shape:", df.shape)
# Out:
# shape: (106520, 34)

# %% [markdown]
# ## Dividing into learn and test

# %%
learn = df.loc[df["alert"]<datetime(2021,7,1,0,0,0)]
test = df.loc[df["alert"]>=datetime(2021,7,1,0,0,0)]
del learn["alert"], test["alert"]
print(learn.shape, test.shape)
# Out:
# (90759, 33) (15761, 33)

# %%
X_train = learn.drop(target, axis=1)
y_train = learn[target]
X_test = test.drop(target, axis=1)
y_test = test[target]

# %%
dico_dataset = {}
dico_dataset["X_train"] = X_train
dico_dataset["y_train"] = y_train
dico_dataset["X_test"] = X_test
dico_dataset["y_test"] = y_test
pickle.dump(dico_dataset, open(folder_name + "/" + "train_test_xy.dat", "wb"))
del dico_dataset

# %% [markdown]
# # Searching best model

# %%
space = {'n_estimators': hp.quniform('n_estimators', 200, 600, 20),
         'max_depth': hp.quniform('max_depth', 10, 15, 1),
         'max_features': hp.quniform('max_features', 0.5, 1, 0.05),
         'max_samples': hp.quniform('max_samples', 0.5, 1, 0.05),
         #'w0': hp.uniform('c0', 1, 5), 
         #'w1': hp.uniform("c1", 1, 5)
        }

header = ["iter", "loss", "acc", "f1-score", "precision", "recall", "c0", "c1", "cm", "report", "params"]
write(folder_name, header)

ITER = 0
trials = Trials()
best = fmin(fn=objective_function,
            space=space,
            algo=tpe.suggest,
            rstate= np.random.default_rng(SEED),
            max_evals=50,
            verbose=False,
            trials=trials)
# Out:
# ------------------------------------------
#
#  1 ::  {'n_estimators': 520, 'max_depth': 13, 'max_features': 0.95, 'max_samples': 0.8, 'class_weight': {0: 1, 1: 2}}
# loss 5986.9130000000005
# acc 77.2
# f1 0.7693701815110343
# cm [[6920 2167]
#  [1427 5247]]
# c0 76.15 c1 78.62
#
# ------------------------------------------
#
#  2 ::  {'n_estimators': 320, 'max_depth': 10, 'max_features': 0.95, 'max_samples': 0.8, 'class_weight': {0: 1, 1: 2}}
# loss 2943.6000000000004
# acc 76.3
# f1 0.7612763960643543
# cm [[6687 2400]
#  [1335 5339]]
# c0 73.59 c1 80.0
#
# ------------------------------------------
#
#  3 ::  {'n_estimators': 260, 'max_depth': 11, 'max_features': 0.8, 'max_samples': 0.55, 'class_weight': {0: 1, 1: 2}}
# loss 2980.2324000000003
# acc 76.86
# f1 0.7665810733699183
# cm [[6791 2296]
#  [1351 5323]]
# c0 74.73 c1 79.76
#
# ------------------------------------------
#
#  4 ::  {'n_estimators': 360, 'max_depth': 14, 'max_features': 0.8, 'max_samples': 0.6, 'class_weight': {0: 1, 1: 2}}
# loss 3004.7702000000004
# acc 77.64
# f1 0.7727842463074726
# cm [[7114 1973]
#  [1551 5123]]
# c0 78.29 c1 76.76
#
# ------------------------------------------
#
#  5 ::  {'n_estimators': 400, 'max_depth': 12, 'max_features': 0.65, 'max_samples': 0.55, 'class_weight': {0: 1, 1: 2}}
# loss 2982.0255
# acc 76.99
# f1 0.7675337640598635
# cm [[6869 2218]
#  [1408 5266]]
# c0 75.59 c1 78.9
#
# ------------------------------------------
#
#  6 ::  {'n_estimators': 500, 'max_depth': 14, 'max_features': 0.7, 'max_samples': 0.6, 'class_weight': {0: 1, 1: 2}}
# loss 3001.544
# acc 77.62
# f1 0.7725050886949686
# cm [[7124 1963]
#  [1564 5110]]
# c0 78.4 c1 76.57
#
# ------------------------------------------
#
#  7 ::  {'n_estimators': 480, 'max_depth': 14, 'max_features': 0.55, 'max_samples': 1.0, 'class_weight': {0: 1, 1: 2}}
# loss 3004.6747499999997
# acc 77.53
# f1 0.7720418757058376
# cm [[7047 2040]
#  [1502 5172]]
# c0 77.55 c1 77.49
#
# ------------------------------------------
#
#  8 ::  {'n_estimators': 220, 'max_depth': 12, 'max_features': 0.85, 'max_samples': 0.9, 'class_weight': {0: 1, 1: 2}}
# loss 2987.6099999999997
# acc 77.0
# f1 0.7678311709402885
# cm [[6830 2257]
#  [1368 5306]]
# c0 75.16 c1 79.5
#
# ------------------------------------------
#
#  9 ::  {'n_estimators': 480, 'max_depth': 13, 'max_features': 0.55, 'max_samples': 0.9, 'class_weight': {0: 1, 1: 2}}
# loss 5992.3922999999995
# acc 77.23
# f1 0.769742643869713
# cm [[6925 2162]
#  [1426 5248]]
# c0 76.21 c1 78.63
#
# ------------------------------------------
#
#  10 ::  {'n_estimators': 340, 'max_depth': 14, 'max_features': 0.7, 'max_samples': 0.75, 'class_weight': {0: 1, 1: 2}}
# loss 2999.5438999999997
# acc 77.52
# f1 0.7717536274815562
# cm [[7078 2009]
#  [1534 5140]]
# c0 77.89 c1 77.02
#
# ------------------------------------------
#
#  11 ::  {'n_estimators': 220, 'max_depth': 15, 'max_features': 0.65, 'max_samples': 0.5, 'class_weight': {0: 1, 1: 2}}
# loss 2983.6415
# acc 77.65
# f1 0.7719260565394115
# cm [[7240 1847]
#  [1675 4999]]
# c0 79.67 c1 74.9
#
# ------------------------------------------
#
#  12 ::  {'n_estimators': 520, 'max_depth': 12, 'max_features': 0.55, 'max_samples': 0.8, 'class_weight': {0: 1, 1: 2}}
# loss 2972.9025
# acc 76.78
# f1 0.7657511339630372
# cm [[6796 2291]
#  [1368 5306]]
# c0 74.79 c1 79.5
#
# ------------------------------------------
#
#  13 ::  {'n_estimators': 320, 'max_depth': 11, 'max_features': 0.8, 'max_samples': 0.85, 'class_weight': {0: 1, 1: 2}}
# loss 2975.9796
# acc 76.74
# f1 0.7656061958038758
# cm [[6737 2350]
#  [1316 5358]]
# c0 74.14 c1 80.28
#
# ------------------------------------------
#
#  14 ::  {'n_estimators': 220, 'max_depth': 14, 'max_features': 0.55, 'max_samples': 0.75, 'class_weight': {0: 1, 1: 2}}
# loss 2997.1442
# acc 77.51
# f1 0.7716054883065182
# cm [[7089 1998]
#  [1546 5128]]
# c0 78.01 c1 76.84
#
# ------------------------------------------
#
#  15 ::  {'n_estimators': 300, 'max_depth': 15, 'max_features': 0.5, 'max_samples': 0.95, 'class_weight': {0: 1, 1: 2}}
# loss 2995.3976000000002
# acc 77.6
# f1 0.7720645819620604
# cm [[7146 1941]
#  [1590 5084]]
# c0 78.64 c1 76.18
#
# ------------------------------------------
#
#  16 ::  {'n_estimators': 560, 'max_depth': 12, 'max_features': 0.6, 'max_samples': 1.0, 'class_weight': {0: 1, 1: 2}}
# loss 2982.69315
# acc 76.88
# f1 0.766814572102422
# cm [[6785 2302]
#  [1342 5332]]
# c0 74.67 c1 79.89
#
# ------------------------------------------
#
#  17 ::  {'n_estimators': 560, 'max_depth': 12, 'max_features': 0.9, 'max_samples': 0.9, 'class_weight': {0: 1, 1: 2}}
# loss 2985.375
# acc 76.95
# f1 0.767381726878559
# cm [[6815 2272]
#  [1361 5313]]
# c0 75.0 c1 79.61
#
# ------------------------------------------
#
#  18 ::  {'n_estimators': 320, 'max_depth': 15, 'max_features': 0.7, 'max_samples': 0.55, 'class_weight': {0: 1, 1: 2}}
# loss 2994.0658
# acc 77.76
# f1 0.7730536596152308
# cm [[7237 1850]
#  [1656 5018]]
# c0 79.64 c1 75.19
#
# ------------------------------------------
#
#  19 ::  {'n_estimators': 300, 'max_depth': 12, 'max_features': 0.55, 'max_samples': 0.9, 'class_weight': {0: 1, 1: 2}}
# loss 2977.3170000000005
# acc 76.83
# f1 0.7662358977218118
# cm [[6793 2294]
#  [1358 5316]]
# c0 74.76 c1 79.65
#
# ------------------------------------------
#
#  20 ::  {'n_estimators': 380, 'max_depth': 11, 'max_features': 1.0, 'max_samples': 0.85, 'class_weight': {0: 1, 1: 2}}
# loss 2966.0583
# acc 76.63
# f1 0.7644581455960962
# cm [[6740 2347]
#  [1336 5338]]
# c0 74.17 c1 79.98
#
# ------------------------------------------
#
#  21 ::  {'n_estimators': 440, 'max_depth': 13, 'max_features': 1.0, 'max_samples': 0.7, 'class_weight': {0: 1, 1: 2}}
# loss 2992.51765
# acc 77.21
# f1 0.7694034341205503
# cm [[6936 2151]
#  [1441 5233]]
# c0 76.33 c1 78.41
#
# ------------------------------------------
#
#  22 ::  {'n_estimators': 440, 'max_depth': 13, 'max_features': 0.9, 'max_samples': 0.7, 'class_weight': {0: 1, 1: 2}}
# loss 5998.458
# acc 77.32
# f1 0.7704210378969698
# cm [[6956 2131]
#  [1444 5230]]
# c0 76.55 c1 78.36
#
# ------------------------------------------
#
#  23 ::  {'n_estimators': 420, 'max_depth': 13, 'max_features': 0.9, 'max_samples': 0.7, 'class_weight': {0: 1, 1: 2}}
# loss 2999.2107
# acc 77.31
# f1 0.7703665010443759
# cm [[6954 2133]
#  [1443 5231]]
# c0 76.53 c1 78.38
#
# ------------------------------------------
#
#  24 ::  {'n_estimators': 460, 'max_depth': 13, 'max_features': 0.75, 'max_samples': 0.7, 'class_weight': {0: 1, 1: 2}}
# loss 6001.068
# acc 77.36
# f1 0.770715315235005
# cm [[6973 2114]
#  [1455 5219]]
# c0 76.74 c1 78.2
#
# ------------------------------------------
#
#  25 ::  {'n_estimators': 600, 'max_depth': 13, 'max_features': 0.75, 'max_samples': 0.65, 'class_weight': {0: 1, 1: 2}}
# loss 2998.9848
# acc 77.34
# f1 0.7705868284405165
# cm [[6972 2115]
#  [1456 5218]]
# c0 76.72 c1 78.18
#
# ------------------------------------------
#
#  26 ::  {'n_estimators': 460, 'max_depth': 13, 'max_features': 0.85, 'max_samples': 0.7, 'class_weight': {0: 1, 1: 2}}
# loss 2983.5292
# acc 77.14
# f1 0.7685376552943751
# cm [[6955 2132]
#  [1471 5203]]
# c0 76.54 c1 77.96
#
# ------------------------------------------
#
#  27 ::  {'n_estimators': 420, 'max_depth': 14, 'max_features': 0.75, 'max_samples': 0.65, 'class_weight': {0: 1, 1: 2}}
# loss 2993.2742
# acc 77.46
# f1 0.7710972630328381
# cm [[7084 2003]
#  [1549 5125]]
# c0 77.96 c1 76.79
#
# ------------------------------------------
#
#  28 ::  {'n_estimators': 560, 'max_depth': 13, 'max_features': 0.85, 'max_samples': 0.65, 'class_weight': {0: 1, 1: 2}}
# loss 5997.4524
# acc 77.37
# f1 0.7707379424521292
# cm [[6990 2097]
#  [1470 5204]]
# c0 76.92 c1 77.97
#
# ------------------------------------------
#
#  29 ::  {'n_estimators': 520, 'max_depth': 10, 'max_features': 0.95, 'max_samples': 0.75, 'class_weight': {0: 1, 1: 2}}
# loss 2949.5388000000003
# acc 76.4
# f1 0.7622201831723524
# cm [[6710 2377]
#  [1342 5332]]
# c0 73.84 c1 79.89
#
# ------------------------------------------
#
#  30 ::  {'n_estimators': 440, 'max_depth': 13, 'max_features': 0.9, 'max_samples': 0.6, 'class_weight': {0: 1, 1: 2}}
# loss 2998.3710000000005
# acc 77.37
# f1 0.7707044484905295
# cm [[6995 2092]
#  [1475 5199]]
# c0 76.98 c1 77.9
#
# ------------------------------------------
#
#  31 ::  {'n_estimators': 380, 'max_depth': 11, 'max_features': 0.95, 'max_samples': 0.8, 'class_weight': {0: 1, 1: 2}}
# loss 2971.5714000000003
# acc 76.71
# f1 0.7652041584552968
# cm [[6750 2337]
#  [1334 5340]]
# c0 74.28 c1 80.01
#
# ------------------------------------------
#
#  32 ::  {'n_estimators': 600, 'max_depth': 15, 'max_features': 0.95, 'max_samples': 0.7, 'class_weight': {0: 1, 1: 2}}
# loss 2984.4408000000003
# acc 77.52
# f1 0.7710784165721166
# cm [[7167 1920]
#  [1623 5051]]
# c0 78.87 c1 75.68
#
# ------------------------------------------
#
#  33 ::  {'n_estimators': 520, 'max_depth': 14, 'max_features': 0.8, 'max_samples': 0.65, 'class_weight': {0: 1, 1: 2}}
# loss 3003.7376
# acc 77.6
# f1 0.7724469268345734
# cm [[7095 1992]
#  [1539 5135]]
# c0 78.08 c1 76.94
#
# ------------------------------------------
#
#  34 ::  {'n_estimators': 400, 'max_depth': 10, 'max_features': 0.65, 'max_samples': 0.8, 'class_weight': {0: 1, 1: 2}}
# loss 2950.4230000000002
# acc 76.31
# f1 0.7616367410307743
# cm [[6628 2459]
#  [1275 5399]]
# c0 72.94 c1 80.9
#
# ------------------------------------------
#
#  35 ::  {'n_estimators': 260, 'max_depth': 13, 'max_features': 0.8, 'max_samples': 0.5, 'class_weight': {0: 1, 1: 2}}
# loss 6000.0435
# acc 77.45
# f1 0.7713392277825436
# cm [[7031 2056]
#  [1498 5176]]
# c0 77.37 c1 77.55
#
# ------------------------------------------
#
#  36 ::  {'n_estimators': 360, 'max_depth': 12, 'max_features': 0.8, 'max_samples': 0.5, 'class_weight': {0: 1, 1: 2}}
# loss 2993.0129999999995
# acc 77.18
# f1 0.7692669264148331
# cm [[6915 2172]
#  [1424 5250]]
# c0 76.1 c1 78.66
#
# ------------------------------------------
#
#  37 ::  {'n_estimators': 240, 'max_depth': 14, 'max_features': 0.75, 'max_samples': 0.55, 'class_weight': {0: 1, 1: 2}}
# loss 3001.497
# acc 77.63
# f1 0.7726040432679455
# cm [[7129 1958]
#  [1567 5107]]
# c0 78.45 c1 76.52
#
# ------------------------------------------
#
#  38 ::  {'n_estimators': 260, 'max_depth': 11, 'max_features': 0.7, 'max_samples': 0.6, 'class_weight': {0: 1, 1: 2}}
# loss 2975.6275499999997
# acc 76.75
# f1 0.7656759329983098
# cm [[6749 2338]
#  [1326 5348]]
# c0 74.27 c1 80.13
#
# ------------------------------------------
#
#  39 ::  {'n_estimators': 280, 'max_depth': 13, 'max_features': 0.85, 'max_samples': 0.55, 'class_weight': {0: 1, 1: 2}}
# loss 2994.9777
# acc 77.37
# f1 0.7705547338045151
# cm [[7017 2070]
#  [1497 5177]]
# c0 77.22 c1 77.57
#
# ------------------------------------------
#
#  40 ::  {'n_estimators': 480, 'max_depth': 14, 'max_features': 0.6, 'max_samples': 0.5, 'class_weight': {0: 1, 1: 2}}
# loss 2992.2134499999997
# acc 77.57
# f1 0.771767727725208
# cm [[7149 1938]
#  [1597 5077]]
# c0 78.67 c1 76.07
#
# ------------------------------------------
#
#  41 ::  {'n_estimators': 360, 'max_depth': 12, 'max_features': 0.75, 'max_samples': 0.6, 'class_weight': {0: 1, 1: 2}}
# loss 2995.9458
# acc 77.17
# f1 0.769316821732021
# cm [[6885 2202]
#  [1396 5278]]
# c0 75.77 c1 79.08
#
# ------------------------------------------
#
#  42 ::  {'n_estimators': 500, 'max_depth': 15, 'max_features': 0.65, 'max_samples': 0.85, 'class_weight': {0: 1, 1: 2}}
# loss 3000.9473
# acc 77.7
# f1 0.7730344553261711
# cm [[7171 1916]
#  [1598 5076]]
# c0 78.91 c1 76.06
#
# ------------------------------------------
#
#  43 ::  {'n_estimators': 200, 'max_depth': 14, 'max_features': 0.8, 'max_samples': 0.95, 'class_weight': {0: 1, 1: 2}}
# loss 6013.203
# acc 77.52
# f1 0.7720779478795234
# cm [[7032 2055]
#  [1488 5186]]
# c0 77.39 c1 77.7
#
# ------------------------------------------
#
#  44 ::  {'n_estimators': 540, 'max_depth': 14, 'max_features': 0.7, 'max_samples': 0.95, 'class_weight': {0: 1, 1: 2}}
# loss 3003.8988
# acc 77.52
# f1 0.7719670332805724
# cm [[7048 2039]
#  [1504 5170]]
# c0 77.56 c1 77.46
#
# ------------------------------------------
#
#  45 ::  {'n_estimators': 200, 'max_depth': 15, 'max_features': 0.6, 'max_samples': 0.95, 'class_weight': {0: 1, 1: 2}}
# loss 3006.2931999999996
# acc 77.73
# f1 0.773431660054051
# cm [[7155 1932]
#  [1578 5096]]
# c0 78.74 c1 76.36
#
# ------------------------------------------
#
#  46 ::  {'n_estimators': 340, 'max_depth': 14, 'max_features': 0.8, 'max_samples': 0.75, 'class_weight': {0: 1, 1: 2}}
# loss 2989.10715
# acc 77.38
# f1 0.7703653927075257
# cm [[7063 2024]
#  [1541 5133]]
# c0 77.73 c1 76.91
#
# ------------------------------------------
#
#  47 ::  {'n_estimators': 580, 'max_depth': 15, 'max_features': 0.85, 'max_samples': 1.0, 'class_weight': {0: 1, 1: 2}}
# loss 2991.824
# acc 77.51
# f1 0.7713289783364067
# cm [[7117 1970]
#  [1575 5099]]
# c0 78.32 c1 76.4
#
# ------------------------------------------
#
#  48 ::  {'n_estimators': 500, 'max_depth': 14, 'max_features': 0.7, 'max_samples': 0.85, 'class_weight': {0: 1, 1: 2}}
# loss 2997.3017000000004
# acc 77.45
# f1 0.7711991273716956
# cm [[7051 2036]
#  [1518 5156]]
# c0 77.59 c1 77.26
#
# ------------------------------------------
#
#  49 ::  {'n_estimators': 460, 'max_depth': 15, 'max_features': 0.65, 'max_samples': 0.8, 'class_weight': {0: 1, 1: 2}}
# loss 3005.189
# acc 77.76
# f1 0.7736040853200437
# cm [[7177 1910]
#  [1595 5079]]
# c0 78.98 c1 76.1
#
# ------------------------------------------
#
#  50 ::  {'n_estimators': 420, 'max_depth': 12, 'max_features': 0.75, 'max_samples': 0.95, 'class_weight': {0: 1, 1: 2}}
# loss 2989.3323500000006
# acc 76.99
# f1 0.7678166000773374
# cm [[6809 2278]
#  [1349 5325]]
# c0 74.93 c1 79.79
# {'max_depth': 14.0, 'max_features': 0.8, 'max_samples': 0.9500000000000001, 'n_estimators': 200.0}

# %% [markdown]
# # Analysis of best model

# %%
best_iter = "43"
best_data = pickle.load(open(folder_name + "/" + "ITER_"+str(best_iter)+".dat", "rb"))
best_data.update(pickle.load(open(folder_name + "/" + "train_test_xy.dat", "rb")))
dfout = best_data["X_test"][["ind_prof"]]
dfout["y_test"] = best_data["y_test"].values
dfout["y_pred"] = best_data["y_pred"]

# %% [markdown]
# ## Accuracy

# %%
acc = round(accuracy_score(dfout["y_test"],dfout["y_pred"])*100, 2)
cm = confusion_matrix(dfout["y_test"], dfout["y_pred"])
c0 = round(cm[0,0]/np.sum(cm[0])*100, 2)
c1 = round(cm[1,1]/np.sum(cm[1])*100, 2)
report = classification_report(dfout["y_test"], dfout["y_pred"], output_dict=True)
dico_metrics = {}
dico_metrics["acc"] = acc
dico_metrics["f1"] = report["macro avg"]["f1-score"]
dico_metrics["c0"] = c0
dico_metrics["c1"] = c1
print("accuracy:", acc)
print("accuracy class 0:", c0, "accuracy class 1:", c1)
print("f1 score:", report["macro avg"]["f1-score"])
# Out:
# accuracy: 77.52
# accuracy class 0: 77.39 accuracy class 1: 77.7
# f1 score: 0.7720779478795234

# %%
for cat_name, cat_sex in [("More vol", 0),
                          ("More prof", 1)]:
    print("Protected:", cat_name)
    print("------------------------------------")
    dfaux = dfout.loc[dfout["ind_prof"]==cat_sex]
    acc = round(accuracy_score(dfaux["y_test"].values, dfaux["y_pred"].values)*100, 2)
    cm = confusion_matrix(dfaux["y_test"].values, dfaux["y_pred"].values)
    c0 = round(cm[0,0]/np.sum(cm[0])*100, 2)
    c1 = round(cm[1,1]/np.sum(cm[1])*100, 2)
    print("accuracy : ", acc)
    print("accuracy class 0: ", c0)
    print("accuracy class 1: ", c1)
    print("\n")
    dico_metrics[cat_name] = {"acc": acc,
                              "c0": c0,
                              "c1": c1,
                             }
# Out:
# Protected: More vol
# ------------------------------------
# accuracy :  77.48
# accuracy class 0:  64.63
# accuracy class 1:  87.66
#
#
# Protected: More prof
# ------------------------------------
# accuracy :  77.58
# accuracy class 0:  87.92
# accuracy class 1:  42.97

# %% [markdown]
# ## Disparate impact

# %%
unpriv_df = dfout[dfout["ind_prof"]==0] 
unpriv_total = unpriv_df.shape[0]

priv_df = dfout[dfout["ind_prof"]==1]
priv_total = priv_df.shape[0]

unpriv_outcomes = unpriv_df[unpriv_df["y_pred"]==1].shape[0]
unpriv_ratio = unpriv_outcomes/unpriv_total

priv_outcomes = priv_df[priv_df["y_pred"]==1].shape[0]
priv_ratio = priv_outcomes/priv_total

disparate_impact = unpriv_ratio/priv_ratio
dico_metrics["disparate"] = disparate_impact

print("Disparate_impact", disparate_impact)
# Out:
# Disparate_impact 3.363926945787856

# %% [markdown]
# ## Smoothed_empirical_differential_fairness

# %%
privileged_groups = [{'ind_prof': 1}] 
unprivileged_groups = [{'ind_prof': 0}] 

ds = best_data['X_test'].copy()
ds["y_pred"] = best_data["y_pred"]
binaryLabelDataset = BinaryLabelDataset(favorable_label=0,
                                        unfavorable_label=1,
                                        df=ds,
                                        label_names=['y_pred'],
                                        protected_attribute_names=['ind_prof'])
metric = BinaryLabelDatasetMetric(binaryLabelDataset, 
                                 unprivileged_groups=unprivileged_groups,
                                 privileged_groups=privileged_groups)
print("SEDF", metric.smoothed_empirical_differential_fairness())
dico_metrics["smoothed"] = metric.smoothed_empirical_differential_fairness()
pickle.dump(dico_metrics, open(folder_name + "/" + "dico_metrics.dat", "wb"))
# Out:
# SEDF 1.2128363675562777
